# %% [markdown]
# # Projet immo / partie inférence

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
df_without_outliers = pd.read_pickle("data/EDA_1_iter.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 df_without_outliers = pd.read_pickle("data/EDA_1_iter.pkl")
#
# NameError: name 'pd' is not defined

# %%
df_without_outliers
# Out:
#           id  longitude  latitude  housing_median_age  total_rooms  \
# 0       2072    -119.84     36.77                 6.0       1853.0
# 1      10600    -117.80     33.68                 8.0       2032.0
# 2       2494    -120.19     36.60                25.0        875.0
# 3       4284    -118.32     34.10                31.0        622.0
# 4      16541    -121.23     37.79                21.0       1922.0
# ...      ...        ...       ...                 ...          ...
# 16507   1099    -121.90     39.59                20.0       1465.0
# 16508  18898    -122.25     38.11                49.0       2365.0
# 16509  11798    -121.22     38.92                19.0       2531.0
# 16510   6637    -118.14     34.16                39.0       2776.0
# 16511   2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# 0               473.0      1397.0       417.0         1.4817
# ...

# %%
import scipy.stats as stats
import statsmodels.api as sm

# OLS for take the residual
independent_variable = "+".join(df_quali.columns)
model = sm.OLS(Y, independent_variable).fit()

# Test of normality on the residuals
print(stats.shapiro(model.resid))

# Plot
pplot = sm.ProbPlot(model.resid, fit = True)
pplot.qqplot(line = 's')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 5
#       2 import statsmodels.api as sm
#       4 # OLS for take the residual
# ----> 5 independent_variable = "+".join(df_quali.columns)
#       6 model = sm.OLS(Y, independent_variable).fit()
#       8 # Test of normality on the residuals
#
# NameError: name 'df_quali' is not defined
